# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
im = Image.open('captured_images/ipynb_img.tif')
arr = np.array(im)

# %%
plt.imshow(arr, cmap='gray')

# %%
print(arr)
print(arr*(2**8 - 1)/(2**16 - 1))
# Out:
# [[16383 16383 16383 ...  8271  8065  9270]
#  [16383 16383 16383 ...  7542  7200  8565]
#  [16383 16383 16383 ...  7520  7519  8513]
#  ...
#  [ 4405  3966  3973 ...  3251  3151  3454]
#  [ 4259  3910  3886 ...  3146  3205  3290]
#  [ 4327  3908  3896 ...  3195  3090  3297]]
# [[0.74612039 0.74612039 0.74612039 ... 0.18239109 0.38084993 0.06948959]
#  [0.74612039 0.74612039 0.74612039 ... 0.34586099 0.01513695 0.3263447 ]
#  [0.74612039 0.74612039 0.74612039 ... 0.26025788 0.25636683 0.12401007]
#  ...
#  [0.13981842 0.43167773 0.45891508 ... 0.64962234 0.26051728 0.43949035]
#  [0.57174029 0.2137789  0.12039368 ... 0.24106203 0.47063401 0.80137331]
#  [0.83633173 0.2059968  0.15930419 ... 0.43172351 0.0231632  0.82861067]]

# %%
arr_8 = (arr.astype(np.float32)*(2**8 - 1)/(2**14 - 1)).astype(np.uint8)
print(arr_8)
# Out:
# [[255 255 255 ... 128 125 144]
#  [255 255 255 ... 117 112 133]
#  [255 255 255 ... 117 117 132]
#  ...
#  [ 68  61  61 ...  50  49  53]
#  [ 66  60  60 ...  48  49  51]
#  [ 67  60  60 ...  49  48  51]]

# %%
plt.imshow(arr_8, cmap='gray')

# %%
np.log2(16384)
# Out:
# np.float64(14.0)

# %%
h, w = arr.shape
h, w
# Out:
# (1536, 1030)

# %%
aspect_ratio = h / w

# %%
aspect_ratio
# Out:
# 1.4912621359223301
